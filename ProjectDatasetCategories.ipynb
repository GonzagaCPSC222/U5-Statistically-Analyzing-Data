# %% [markdown]
# # "Quantified Self" Project Dataset Categories

# %%
import matplotlib.pyplot as plt
import pandas as pd

# note two students did not submit a project proposal
# and therefore have "??" for their category
# I emailed both of you, please email me back :)
categories = ["Music", 
"Finance", 
"Music", 
"Finance", 
"Music", 
"Social", 
"App/Screen Usage", 
"??", 
"App/Screen Usage", 
"Location", 
"Music", 
"Music", 
"App/Screen Usage", 
"Entertainment", 
"Finance", 
"Music", 
"Music", 
"Music", 
"Exercise", 
"??", 
"Exercise", 
"Exercise", 
"App/Screen Usage", 
"Music", 
"Sleep", 
"Exercise", 
"Music", 
"App/Screen Usage"]

cat_ser = pd.Series(categories)
cat_counts_ser = cat_ser.value_counts()

plt.bar(cat_counts_ser.index, cat_counts_ser)
plt.xticks(rotation=45, horizontalalignment="right")
plt.xlabel("Dataset Category")
plt.ylabel("Project Counts")
plt.title("CPSC 222 Project Dataset Categories")
plt.show()
